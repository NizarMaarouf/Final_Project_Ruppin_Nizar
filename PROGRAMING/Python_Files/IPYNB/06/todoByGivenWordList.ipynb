# %%
import csv
referencePath = (r'C:\Users\nizar.maarouf\Desktop\Final_Progect_Ruppin\DATA\CSV_Files\Data_Encoding.csv')
givenParagraph = (r'C:\Users\nizar.maarouf\Desktop\Final_Progect_Ruppin\DATA\TXT_FILES\input_Data.txt')

def WordToVector(givenWord):
    File = open(referencePath,'r',encoding="utf8")
    Reader = csv.reader(File)
    Data = list(Reader)
    returnValue = []
    for data  in Data:
        if((data) != ['', '', '', '', '', '', '', '', '', '']):
            if(data[0] == givenWord):
                returnValue = data
                break
         

    File.close()  
    
    return returnValue
    
def main(): 

    print()
    with open(givenParagraph, 'r',encoding="utf8") as file2:
        for element in file2:
            for word in element.split(' '):
                givenWord = word.strip()
                full_vector=WordToVector(givenWord)
                outcome = []

                if(full_vector != [] ):
                    #exist
                    #Filter vector
                    outcome = full_vector[len(full_vector) -1]
                    newVector = full_vector[1:len(full_vector)- 1]
                    print('Found - '+givenWord)
                    print(newVector)
                    print('outcome - ' + outcome)

                else:
                    # not exist
                    print('Wrong input - '+ givenWord)


                print('\n')

main()
# Out:
# Found - إسلام
# ['4', '1', '0', '0', '0', '2', '0', '2']
# outcome - 0
#
#
# Found - أسامه
# ['5', '1', '0', '0', '0', '2', '0', '3']
# outcome - 0
#
#
# Found - أسماء
# ['5', '1', '0', '0', '0', '2', '0', '1']
# outcome - 0
#
#
# Found - أسيل
# ['4', '1', '0', '0', '0', '2', '0', '1']
# outcome - 0
#
#
# Wrong input -
#
#
# Found - أنور
# ['4', '1', '0', '0', '0', '2', '0', '1']
# outcome - 0
#
#
# Found - أبرار
# ['5', '1', '0', '0', '0', '2', '0', '1']
# outcome - 0
#
#
# Found - أبٌ
# ['2', '3', '0', '0', '0', '2', '0', '1']
# outcome - 0
#
#
# Found - أم
# ['2', '6', '0', '0', '0', '2', '0', '3']
# outcome - 0
#
#
# Found - أخٌ
# ['2', '3', '0', '0', '0', '2', '0', '3']
# outcome - 0
#
#
# Found - أسره
# ['4', '6', '0', '0', '0', '2', '0', '3']
# outcome - 0
