# %%
import csv
referencePath = (r'C:\Users\nizar.maarouf\Desktop\project_2021\Data_Encoding.csv')
givenParagraph = (r'C:\Users\nizar.maarouf\Desktop\project_2021\input.txt')

def WordToVector(givenWord):
    File = open(referencePath,'r',encoding="utf8")
    Reader = csv.reader(File)
    Data = list(Reader)
    returnValue = []
    for data  in Data:
        if((data) != ['', '', '', '', '', '', '', '', '', '']):
            if(data[0] == givenWord):
                returnValue = data
                break
         

    File.close()  
    
    return returnValue
    
def main(): 

    print()
    with open(givenParagraph, 'r',encoding="utf8") as file2:
        for element in file2:
            for word in element.split(' '):
                givenWord = word.strip()
                full_vector=WordToVector(givenWord)
                outcome = []

                if(full_vector != [] ):
                    #exist
                    #Filter vector
                    outcome = full_vector[len(full_vector) -1]
                    newVector = full_vector[1:len(full_vector)- 1]
                    print('Found - '+givenWord)
                    print(newVector)
                    print('outcome - ' + outcome)

                else:
                    # not exist
                    print('Wrong input - '+ givenWord)


                print('\n')

main()
# Out:
# Wrong input - يِعتبر
#
#
# Wrong input - الإيقاعُ
#
#
# Wrong input - الموسيقيّ
#
#
# Wrong input - لقلب
#
#
# Wrong input - الأمّ
#
#
# Wrong input - أوّلَ
#
#
# Wrong input - لحن
#
#
# Wrong input - بشريّ
#
#
# Wrong input - عرفه
#
#
# Wrong input - الإنسان،
#
#
# Wrong input - منذ
#
#
# Wrong input - تمام
#
#
# Wrong input - الشّهر
#
#
# Wrong input - الرّابع
#
#
# Wrong input - لتكوينه
#
#
# Wrong input - البنيويّ
#
#
# Wrong input - والعضويّ
#
#
# Wrong input - من
#
#
# Wrong input - دورة
#
#
# Wrong input - حياته
#
#
# Wrong input - الجَنينيّة،
#
#
# Wrong input -
#
#
# Wrong input - لأنّ
#
#
# Wrong input - حاسّة
#
#
# Wrong input - السّمع
#
#
# Wrong input - تعمل
#
#
# Wrong input - وتكتمل
#
#
# Wrong input - في
#
#
# Wrong input - ذلك
#
#
# Found - الوقت
# ['5', '6', '0', '0', '0', '1', '1', '1']
# outcome - 1
#
#
# Wrong input - من
#
#
# Wrong input - نشأته
#
#
# Wrong input - الأولى،
#
#
# Wrong input - ولهذا
#
#
# Wrong input - نعرف
#
#
# Wrong input - كيف
#
#
# Wrong input - يستطيع
#
#
# Wrong input - الطّفلُ
#
#
# Found - أن
# ['2', '0', '0', '1', '0', '1', '0', '1']
# outcome - 0
#
#
# Wrong input - يظلّ
#
#
# Wrong input - هادئًا
#
#
# Wrong input - في
#
#
# Wrong input - رَحْم
#
#
# Wrong input - أمّه
#
#
# Wrong input - خلال
#
#
# Wrong input - فترة
#
#
# Wrong input - الحمل
#
#
# Wrong input - المتبقّية،
#
#
# Wrong input -
#
#
# Wrong input - حيث
#
#
# Wrong input - يُصغي
#
#
# Found - إلى
# ['3', '0', '0', '1', '0', '1', '0', '2']
# outcome - 0
#
#
# Wrong input - أجمل
#
#
# Wrong input - موسيقى
#
#
# Wrong input - إلهيّة
#
#
# Wrong input - مؤلّفُها
#
#
# Wrong input - وملحِّنُها
#
#
# Wrong input - وعازفها
#
#
# Wrong input - الأوّل
#
#
# Wrong input - هو
#
#
# Wrong input - القلب،
#
#
# Wrong input - وكذلك
#
#
# Wrong input - يُعتبر
#
#
# Wrong input - القلب
#
#
# Wrong input - العضوَ
#
#
# Wrong input - الوظيفيّ
#
#
# Wrong input - الأوّل
#
#
# Wrong input - في
#
#
# Wrong input - حياة
#
#
# Wrong input - الإنسان،
#
#
# Wrong input -
#
#
# Wrong input - حيث
#
#
# Wrong input - يعمل
#
#
# Wrong input - منذ
#
#
# Wrong input - اليوم
#
#
# Wrong input - الواحد
#
#
# Wrong input - والعشرين
#
#
# Wrong input - في
#
#
# Wrong input - تكوينه
#
#
# Wrong input - الأوّليّ.
#
#
# Wrong input -
#
#
# Wrong input - وفي
#
#
# Wrong input - هذا
#
#
# Found - الوقت
# ['5', '6', '0', '0', '0', '1', '1', '1']
# outcome - 1
#
#
# Wrong input - يتناغم
#
#
# Wrong input - قلبُ
#
#
# Wrong input - الجنين
#
#
# Wrong input - مع
#
#
# Wrong input - قلب
#
#
# Wrong input - أمّه
#
#
# Wrong input - ليعزفا
#
#
# Wrong input - معًا
#
#
# Wrong input - أوّل
#
#
# Wrong input - لحن
#
#
# Wrong input - بشريّ
#
#
# Wrong input - مشترك
#
#
# Wrong input - عرفه
#
#
# Wrong input - التّأريخ،
#
#
# Found - ألا
# ['3', '0', '0', '1', '0', '1', '0', '1']
# outcome - 0
#
#
# Wrong input - وهو
#
#
# Wrong input - لحن
#
#
# Wrong input - الحبّ،
#
#
# Wrong input -
#
#
# Wrong input - ويبكي
#
#
# Wrong input - الطّفل
#
#
# Wrong input - بصورة
#
#
# Wrong input - حادّة
#
#
# Wrong input - بعد
#
#
# Wrong input - الولادة
#
#
# Wrong input - مباشرة،
#
#
# Wrong input - تعبيرًا
#
#
# Wrong input - عن
#
#
# Wrong input - سَخَطه
#
#
# Wrong input - ولابتعاده
#
#
# Wrong input - القَسْريّ
#
#
# Wrong input - عن
#
#
# Wrong input - سماع
#
#
# Wrong input - موسيقى
#
#
# Wrong input - قلب
#
#
# Wrong input - أمّه!
#
#
# Found - إسلام
# ['4', '1', '0', '0', '0', '2', '0', '2']
# outcome - 0
